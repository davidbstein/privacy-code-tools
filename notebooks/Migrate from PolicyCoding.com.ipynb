# %%
cd ..
# Out:
# /Users/stein/repos/privacy-code-tools

# %%
from coder.api import models

# %%
import requests, json

# %%
API_PREFIX = "http://policycoding.com/api/"

# %%
s = requests.Session()

# %%
s.cookies.set("sessionid", "iw5nf2lcj3d3c4bhyp6bd37adwl8rrjc")
# Out:
# Cookie(version=0, name='sessionid', value='iw5nf2lcj3d3c4bhyp6bd37adwl8rrjc', port=None, port_specified=False, domain='', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False)

# %%
coding_instances = json.loads(s.get(f"{API_PREFIX}coding_instance/?page=14").content)

# %%
coding_instances.keys()
# Out:
# dict_keys(['detail'])

# %%
def get_results(endpoint):
    to_ret = []
    res = json.loads(s.get(f"{API_PREFIX}{endpoint}").content)
    to_ret.extend(res['results'])
    while 'next' in res and res['next']:
        print(res['next'])
        res = json.loads(s.get(res['next']).content)
        to_ret.extend(res['results'])
    return to_ret

# %%
# confirm that this is a "Django Shell-Plus Kernel"
from aws_requests_auth.boto_utils import BotoAWSRequestsAuth
from coder.api import models
from io import BytesIO
import bs4
import csv
import codecs
import datetime
import json
import os
import requests
import urllib
import zipfile

# %%
# IN-MEMORY CACHES
try:
    print(_INFOS.get("test"), len(domain_set))
except:
    _INFOS = {}
    domain_set = set()
# Out:
# None 0

# %%
coding_instances = get_results("coding_instance")
policy_instances = get_results("policy_instance")
policies = get_results("policy")

# %%
codings = get_results('coding')

# %%
policies_by_id = {p['id']: p for p in policies}
policy_instances_by_id = {pi['id']: pi for pi in policy_instances}
codings_by_id = {c['id']: c for c in codings}
#site_to_old_policy

# %%
for v in site_to_old_policy.values():
    v['_progress'] = {"coder_progress_pairs": []}

# %%
policy_progress_2020 = []
for ci in coding_instances:
    if ci['coding_id'] < 10 or ci['coder_email'] in ['dbs438@nyu.edu', 'davidbstein@gmail.com']:
        continue
    question_ids = [c['identifier'] for c in codings_by_id[10]['questions']]
    pi = policy_instances_by_id[ci['policy_instance_id']]
    p = policies_by_id[pi['policy_id']]
    policy_progress_2020.append({
        'site_name': p['site_name'],
        'coder': ci['coder_email'],
        'progress': len(list(filter((lambda k: k in question_ids), ci['coding_values'].keys())))
    })

# %%
from collections import defaultdict

progress_2020_by_site = defaultdict(dict)

for coding_entry in policy_progress_2020:
    progress_2020_by_site[coding_entry['site_name']][coding_entry['coder']] = coding_entry['progress']

for site, progress in progress_2020_by_site.items():
    print(site, progress)
# Out:
# lonelyplanet.com {'saz312@nyu.edu': 220, 'florencia.m.wurgler@gmail.com': 26, 'ams1987@nyu.edu': 131}
# airliners.net {'cv729@nyu.edu': 137, 'florencia.m.wurgler@gmail.com': 18, 'lav345@nyu.edu': 212}
# webmediabrands.com {'cv729@nyu.edu': 120, 'lav345@nyu.edu': 218}
# cbsinteractive.com {'cv729@nyu.edu': 136, 'florencia.m.wurgler@gmail.com': 2, 'lav345@nyu.edu': 217}
# aboutus.disaboom.com {'cv729@nyu.edu': 110, 'florencia.m.wurgler@gmail.com': 0, 'lav345@nyu.edu': 218, 'ss11617@nyu.edu': 224}
# dpreview.com {'spk376@nyu.edu': 217, 'ams1987@nyu.edu': 110}
# Twitter.com {'ss11617@nyu.edu': 0}
# greensingles.com {'cv729@nyu.edu': 136, 'florencia.m.wurgler@gmail.com': 21, 'lav345@nyu.edu': 217}
# 23andme.com {'ams1987@nyu.edu': 140, 'spk376@nyu.edu': 217, 'florencia.m.wurgler@gmail.com': 1}
# imgur.com {'amm1837@nyu.edu': 227, 'aet414@nyu.edu': 74}
# myshopify.com {'amm1837@nyu.edu': 227, 'aet414@nyu.edu': 5}
# ...

# %%
def new_policy_by_site():
    return {p.site_name: p for p in models.Policy.objects.all()}

# %%
# confirm that this is a "Django Shell-Plus Kernel"
from aws_requests_auth.boto_utils import BotoAWSRequestsAuth
from coder.api import models
from io import BytesIO
import bs4
import csv
import codecs
import datetime
import json
import os
import requests
import urllib
import zipfile

def get_top_1m(date):
    url = f"https://web.archive.org/web/{date:%Y%m%d%H%M%S}/s3.amazonaws.com/alexa-static/top-1m.csv.zip"
    top_1m = zipfile.ZipFile(BytesIO(requests.get(url).content))
    with top_1m.open("top-1m.csv", 'r') as f:
        sites = list(csv.reader(codecs.iterdecode(f, 'utf-8')))
    return [(s[1], int(s[0])) for s in sites]

def _clean(entry):
    if len(entry) == 1 and 'value' in entry:
         return entry['value']
    return entry

def _expand_soup(s):
    name = s.name
    if name == "aws:country":
        name=f"aws:{s.attrs['code']}"
    if name == "aws:contributingsubdomains":
        children_expanded = [
            ss[1] for ss in 
            filter(
                lambda x:x, 
                map(_expand_soup, s.children)
            )
        ]
        return (name[4:], children_expanded)
    if hasattr(s, "children") and name.startswith("aws:"):
        children_expanded = {
            k:v for k,v in 
            filter(
                lambda x:x, 
                map(_expand_soup, s.children)
            )
        }
        return (name[4:], _clean(children_expanded))
    elif str(s) == "\n":
        pass
    else:
        return ("value", s)

def _process_response(resp):
    soup = bs4.BeautifulSoup(resp.content)
    return _expand_soup(soup.find("aws:alexa"))[1]

def _get(d, path, default=None):
    cur = d
    for p in path.split("."):
        cur = cur.get(p, None)
        if cur == None:
            return default
    return cur

def info_to_domains(info):
    return _get(info, 'contentdata.owneddomains', {})


def info_to_policy(info):
    online_since = _get(info, 'contentdata.sitedata.onlinesince')
    if online_since:
        try:
            online_since = datetime.datetime.strptime(online_since, "%d-%b-%Y")
        except:
            pass
        try:
            online_since = datetime.datetime.strptime(online_since, "%d-%b-%y")
        except:
            pass
    return models.Policy(
        company_name= _get(info, 'contentdata.sitedata.title'),
        site_name = _get(info, 'contentdata.dataurl'),
        alexa_rank = _get(info, 'trafficdata.rank') or None,
        alexa_rank_US = _get(info, 'trafficdata.rankbycountry.US.rank') or None,
        locale=_get(info, "contentdata.language.locale"),
        start_date = online_since,
        meta = info,
        progress = {"loaded": {}, "merged": {}, "coding_1": {}, "coding_2": {}, "duplicate": False, "coded_2018": 0, "coded_2020": 0}
    )

def get_site_info(url):
    """ Pull top site data from Alexa top site rankings. $0.036 / query """
    if url in _INFOS:
        #print("CACHE")
        return _INFOS[url]
    response_group = "Rank,RankByCountry,UsageStats,AdultContent,Speed,Language,OwnedDomains,SiteData"
    auth = BotoAWSRequestsAuth(
      aws_host='awis.us-west-1.amazonaws.com',
      aws_region='us-west-1',
      aws_service='awis'
    )
    api_url = 'https://awis.us-west-1.amazonaws.com/api'
    query_params = urllib.parse.quote(
      f'Action=UrlInfo&ResponseGroup={response_group}&Url={url}',
      safe = '/-_.~=&'
    )
    to_ret = _process_response(requests.get(f"{api_url}?{query_params}", auth=auth))
    _INFOS[url] = to_ret
    return to_ret

# %%
for site, progress in progress_2020_by_site.items():
    if site in new_policy_by_site:
        if progress.get('florencia.m.wurgler@gmail.com',0) >= 1:
            pass
#             new_policy_by_site[site].progress['coded_2020'] = True
#             new_policy_by_site[site].save()
        elif len([1 for coder, count in progress.items() if 'gmail' not in coder and count>130]) >= 2:
            pass
#             print(site)
#             new_policy_by_site[site].progress['coded_2020'] = 'unmerged'
#             new_policy_by_site[site].save()
    else:
        policy = info_to_policy(get_site_info(site))
        if progress.get('florencia.m.wurgler@gmail.com',0) >= 1:
            #print(site)
            policy.progress['coded_2020'] = True
        elif len([1 for coder, count in progress.items() if 'gmail' not in coder and count>130]) >= 2:
            #print(site)
            policy.progress['coded_2020'] = 'unmerged'
        #policy.save()
# Out:
# CACHE
# lonelyplanet.com
# CACHE
# airliners.net
# CACHE
# CACHE
# cbsinteractive.com
# CACHE
# aboutus.disaboom.com
# CACHE
# CACHE
# CACHE
# greensingles.com
# CACHE
# 23andme.com
# CACHE
# twoplustwo.com
# CACHE
# CACHE
# metrodate.com
# CACHE
# slickdeals.net
# CACHE
# CACHE
# christianmingle.com
# CACHE
# CACHE
# CACHE
# aq.com
# CACHE
# CACHE
# helix.com
# CACHE
# signonsandiego.com
# CACHE
# ubi.com
# CACHE
# CACHE
# CACHE
# purevolume.com
# CACHE
# CACHE
# CACHE
# whitewomenblackmen.com
# CACHE
# dailystrength.org
# CACHE
# arstechnica.com
# CACHE
# CACHE
# wordreference.com
# CACHE
# CACHE
# CACHE
# CACHE
# foursquare.com
# CACHE
# ebaumsworld.com
# CACHE
# chemistry.com
# CACHE
# heremedia.com
# CACHE
# CACHE
# CACHE
# newgrounds.com
# CACHE
# CACHE
# CACHE
# CACHE
# CACHE
# CACHE
# CACHE
# CACHE
# CACHE
# hulu.com
# CACHE
# sequencing.com
# CACHE
# CACHE
# CACHE
# dictionary.com
# CACHE
# CACHE
# CACHE
# CACHE
# yardbarker.com
# CACHE
# taylorswift.com
# CACHE
# amd.com
# ...

# %%
json.dumps("""rentboy.com
hustler.com
swingersboard.com
xtube.com
pornhub.com
brazzers.com
tube8.com
chaturbate.com
myfreecams.com/
nudevista.com/
youporn.com/
streamate.com
xvideos.com
xhamster.com
xnxx.com
redtube.com
livejasmin.com
imagefap.com/
beeg.com
youjizz.com/
amiestreet.com
mubi.com
babycenter.com
bigtent.com
blogger.com
bolt.com
collegeblender.com
dailybooth.com
dailystrength.org
aboutus.disaboom.com
epernicus.com
eons.com
exploroo.com
filmaffinity.com
foursquare.com
gays.com
yammer.com
indabamusic.com
italki.com
itsmy.com
kiwibox.com
zooppa.com
listography.com
us.mouthshut.com
craveonline.com
my.opera.com
opendiary.com
partnerup.com
presently.com
quarterlife.com
raptr.com
researchgate.net
reverbnation.com
sciencestage.com
sharethemusic.com
stumbleupon.com
talkbiznow.com
teachstreet.com
tumblr.com
weeworld.com
cutestat.com
wiserearth.org
xt3.com
chemistry.com
compatiblepartners.net
eharmony.com
.com", "playboy.com", "plurk.com", "passportstamp.com", "ravelry.com", "reunion.com", "shelfari.com", "sonico.com", "stickam.com", "student.com", "taltopia.com", "twitter.com", "tribe.net", "outeverywhere.com", "faces.com", "vampirefreaks.com", "movabletype.com", "uk.wasabi.com", "wayn.com", "about.crunchbase.com", "help.xanga.com", "xing.com", "yelp.com", "dropbox.com", "amazon.com", "sugarsync.com", "music.google.com", "pandora.com", "twilio.com", "grooveshark.com", "spideroak.com", "one.ubuntu.com", "wuala.com", "syncplicity.com", "support.getcloudapp.com", "minus.com", "zumodrive.com", "rollbase.com", "caspio.com", "squarespace.com", "salesforce.com", "reddit.com", "google.com", "books.google.com", "wallet.google.com", "pinterest.com"]

# %%
OPP_LIST = ["abcnews.go.com", "abita.com", "adweek.com", "allrecipes.com", "allstate.com", "amazon.co.uk", "amazon.com", "archives.gov", "austincc.edu", "autoblog.com", "barnesandnoble.com", "basketball-reference.com", "boardgamegeek.com", "buffalowildwings.com", "cariboucoffee.com", "chasepaymentech.com", "chicagomarathon.com", "cincymuseum.org", "citizen.org", "coffeereview.com", "communitycoffee.com", "dailyillini.com", "dailynews.com", "dairyqueen.com", "dcccd.edu", "dictionary.reference.com", "disinfo.com", "dogbreedinfo.com", "drinksmixer.com", "earthkam.org", "eatchicken.com", "education.jlab.org", "esquire.com", "essence.com", "everydayhealth.com", "fightingillini.com", "foodallergy.org", "fool.com", "fortune.com", "fredericknewspost.com", "freep.com", "gamerankings.com", "gamestop.com", "gawker.com", "geocaching.com", "gwdocs.com", "hemmings.com", "honda.com", "ideas.repec.com", "ifsa-butler.org", "imdb.com", "instagram.com", "ironhorsevineyards.com", "jibjab.com", "kaleidahealth.org", "kraftrecipes.com", "latinpost.com", "lids.com", "liquor.com", "loc.gov", "lodgemfg.com", "lynda.com", "miaminewtimes.com", "military.com", "minecraft.gamepedia.com", "mlb.mlb.com", "mohegansun.com", "motortrend.com", "msn.com", "nationalzoo.si.edu", "naturalnews.com", "nbc.com", "neworleansonline.com", "news.yahoo.com", "newsbusters.com", "nytimes.com", "ocregister.com", "opensecrets.org", "pbs.org", "playstation.com", "post-gazette.com", "primagames.com", "reddit.com", "redorbit.com", "restaurantnews.com", "rockstargame.com", "sci-news.com", "sciencemag.org", "sites.google.com", "sites.google.com", "sltrib.com", "solarviews.com", "store.steampowered.com", "style.com", "tangeroutlet.com", "taylorswift.com", "ted.com", "tgifridays.com", "theatlantic.com", "thecarconnection.com", "thefreedictionary.com", "thehill.com", "theverge.com", "ticketmaster.com", "tulsaworld.com", "uh.edu", "uptodate.com", "usa.gov", "vikings.com", "walmart.com", "washingtonian.com", "washingtonpost.com", "wikitravel.org", "wnep.com", "wsmv.com", "yardbarker.com", "zacks.com"]

# %%
len(OPP_LIST)
# Out:
# 117

# %%
site_to_p = new_policy_by_site()
for site in PP_V7:
    site = site.replace("/", '')
    if site in site_to_p:
        policy = site_to_p[site]
    else:
        print(f"new: {site}")
        policy = info_to_policy(get_site_info(site))
        policy.site_name = site
    policy.categories.append("PP_V7")
    policy.progress['coded_2018'] = True
    policy.categories = list(set(policy.categories))
    policy.save()

# %%
_INFOS.keys()

# %% [markdown]
# ```
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ```
